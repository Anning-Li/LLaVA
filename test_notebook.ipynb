# %% [markdown]
# # Requirements

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !git clone https://github.com/haotian-liu/LLaVA.git
# %cd LLaVA/
# Out:
# Cloning into 'LLaVA'...
# remote: Enumerating objects: 2297, done.
# remote: Total 2297 (delta 0), reused 0 (delta 0), pack-reused 2297 (from 1)
# Receiving objects: 100% (2297/2297), 13.71 MiB | 6.69 MiB/s, done.
# Resolving deltas: 100% (1405/1405), done.
# /content/LLaVA

# %%
# !mkdir -p model_bank/llava-1.5-7b-hf

# %%
# !ls
# Out:
# cog.yaml  images   llava       predict.py      README.md
# docs	  LICENSE  playground  pyproject.toml  scripts

# %%
# !huggingface-cli download liuhaotian/llava-v1.5-7b \
    --local-dir /content/LLaVA/model_bank/llava-1.5-7b-hf \
    --local-dir-use-symlinks False

# !huggingface-cli download openai/clip-vit-large-patch14 \
  --local-dir /content/LLaVA/model_bank/llava-1.5-7b-hf/vision_tower \
  --local-dir-use-symlinks False
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/commands/download.py:141: FutureWarning: Ignoring --local-dir-use-symlinks. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# ⚠️  Warning: 'huggingface-cli download' is deprecated. Use 'hf download' instead.
# Fetching 11 files:   0% 0/11 [00:00<?, ?it/s]Downloading 'pytorch_model-00001-of-00002.bin' to '/content/LLaVA/model_bank/llava-1.5-7b-hf/.cache/huggingface/download/fPHULxv55kAe7RSfHmmL42LIc1I=.492fdfa63cf314097d99da81a3586d54a97adc1471a0ae0535f5caa269b86314.incomplete'
# ...
#
# pytorch_model.bin.index.json: 0.00B [00:00, ?B/s]Downloading 'mm_projector.bin' to '/content/LLaVA/model_bank/llava-1.5-7b-hf/.cache/huggingface/download/NRUs2AzHWcGkekTW7KYb6HFmz6w=.be33a3b477e091832a3c8a9fabf5769c43b4cb2c161fc8c464b7bb214f16143a.incomplete'
# pytorch_model.bin.index.json: 27.1kB [00:00, 13.9MB/s]
# ...

# %%
# %cd recipeqa/
# !unzip test.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: test/images-qa/the-gingerbread-man-cake_14_4.jpg
#   inflating: __MACOSX/test/images-qa/._the-gingerbread-man-cake_14_4.jpg
#   inflating: test/images-qa/monkey-brains-cocktail_2_2.jpg
#   inflating: __MACOSX/test/images-qa/._monkey-brains-cocktail_2_2.jpg
#   inflating: test/images-qa/surprise-cake_0_0.jpg
#   inflating: __MACOSX/test/images-qa/._surprise-cake_0_0.jpg
#   inflating: test/images-qa/watermelon-carving-basics-roses_10_2.jpg
#   inflating: __MACOSX/test/images-qa/._watermelon-carving-basics-roses_10_2.jpg
#   inflating: test/images-qa/milk-free-bubble-tea_1_0.jpg
#   inflating: __MACOSX/test/images-qa/._milk-free-bubble-tea_1_0.jpg
#   inflating: test/images-qa/chocolate-buns_9_1.jpg
#   inflating: __MACOSX/test/images-qa/._chocolate-buns_9_1.jpg
#   inflating: test/images-qa/crispy-nendran-banana-chips_6_5.jpg
#   inflating: __MACOSX/test/images-qa/._crispy-nendran-banana-chips_6_5.jpg
# ...

# %%
# %cd ..
# Out:
# /content/LLaVA

# %% [markdown]
# # Test

# %%
# !python test_ordering.py
# Out:
# 2025-11-20 00:29:39.977290: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-20 00:29:39.994191: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763598580.015615    9624 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763598580.022048    9624 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python test_coherence.py
# Out:
# 2025-11-20 00:43:47.674596: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-20 00:43:47.691550: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763599427.712761   13289 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763599427.719135   13289 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python test_explaining.py
# Out:
# 2025-11-20 00:46:19.305758: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-20 00:46:19.323431: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763599579.345129   13991 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763599579.351606   13991 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
